# %%
import gymnasium
import gym_gridworlds
from gym_gridworlds.observation_wrappers import MatrixWithGoalWrapper, MatrixWrapper, CoordinateWrapper, AddGoalWrapper

# %%
env = gymnasium.make("Gym-Gridworlds/FourRooms-Original-13x13-v0", start_pos = None, random_goals=False)
print(f"Max episode steps for {env}: {env.spec.max_episode_steps}")

env = AddGoalWrapper(env)
# Out:
# Max episode steps for <TimeLimit<OrderEnforcing<PassiveEnvChecker<Gridworld<Gym-Gridworlds/FourRooms-Original-13x13-v0>>>>>: 200

# %%
obs, _ = env.reset(seed=42)
obs
# Out:
# [np.int64(24), np.int64(154)]

# %%
print(obs[..., 0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 print(obs[..., 0])
#
# IndexError: invalid index to scalar variable.
